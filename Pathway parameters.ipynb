# %%
import pathSim
import importlib
importlib.reload(pathSim)
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# Traceback (most recent call last):
#
#   File "/home/pablo/anaconda2/envs/doe/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3265, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-135-a26c406da360>", line 3, in <module>
#     importlib.reload(pathSim)
#
#   File "/home/pablo/anaconda2/envs/doe/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#
#   File "/mnt/SBC1/code/pathsim/pathSim.py", line 387
#     selections.append(i)
#                         ^
# ...

# %% [markdown]
# ## No induction, no enzyme leakage, no enzyme degradation

# %%
# Kd = 1e-4
pw, ds, M, results, par, diagnostics = pathSim.SimulateDesign(steps=1, show=True, nplasmids=1, variants=1, npromoters=3, timespan=12*3600) 
pathSim.PlotResponse()
# Out:
# Design
# Build
# No handles with labels found to put in legend.

# %% [markdown]
# ## Induction, no catalysis, no leakage, no degradation

# %%
# n = 2
# kf1 = 1e-3
# kr1 = 1e-6

pw, ds, M, results, par, diagnostics = pathSim.SimulateDesign(steps=1, show=True, nplasmids=1, variants=1, npromoters=3, timespan=12*3600) 
pathSim.PlotResponse()
# Out:
# Design
# Build
# No handles with labels found to put in legend.

# %% [markdown]
# ## Induction, no catalysis

# %%
# kdeg = 1e-5
# kleak = 1e-8
pw, ds, M, results, par, diagnostics = pathSim.SimulateDesign(steps=1, show=True, nplasmids=1, variants=1, npromoters=3, timespan=12*3600) 
pathSim.PlotResponse()
# Out:
# Design
# Build
# No handles with labels found to put in legend.

# %%
ds
# Out:
#              time  [m1_Substrate]  [m1_Product]   [m1_Enzyme]  [m1_Inducer]  \
# 0        0.000000    1.000000e-09  0.000000e+00  0.000000e+00  1.000000e-06
# 1       43.243243    9.948515e-10  8.347992e-13  3.908278e-08  9.597878e-07
# 2       86.486486    9.881806e-10  3.217482e-12  7.376046e-08  9.226920e-07
# 3      129.729730    9.802040e-10  6.937697e-12  1.042466e-07  8.883615e-07
# 4      172.972973    9.711161e-10  1.180604e-11  1.310126e-07  8.564982e-07
# 5      216.216216    9.610923e-10  1.765173e-11  1.544700e-07  8.268445e-07
# 6      259.459459    9.502891e-10  2.432193e-11  1.749790e-07  7.991777e-07
# 7      302.702703    9.388458e-10  3.168030e-11  1.928549e-07  7.733044e-07
# 8      345.945946    9.268863e-10  3.960582e-11  2.083745e-07  7.490566e-07
# 9      389.189189    9.145202e-10  4.799097e-11  2.217836e-07  7.262865e-07
# 10     432.432432    9.018439e-10  5.674052e-11  2.333007e-07  7.048626e-07
# ...

# %% [markdown]
# ## Catalysis

# %%
pw, ds, M, results, par, diagnostics = pathSim.SimulateDesign(steps=1, show=True, nplasmids=1, variants=1, npromoters=3, timespan=12*3600) 
pathSim.PlotResponse()
# Out:
# Design
# Build
# No handles with labels found to put in legend.

# %%
par
# Out:
# {'Copy_number': array([14.08318586]),
#  'Expression': array([  2.4658791 , 460.62743915, 533.98216125]),
#  'Step': [[{'Catalysis_Km': (0.001, 1e-05),
#     'Catalysis_kcat': (1, 0.01),
#     'Degradation_k2': (1e-05, 1.0000000000000001e-07),
#     'Induction_n': (2, 0.02),
#     'Induction_kf1': (0.001, 1e-05),
#     'Induction_kr1': (1e-06, 1e-08),
#     'Leakage_vl': (1e-08, 1e-10)}]]}
